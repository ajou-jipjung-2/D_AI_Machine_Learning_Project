# %%
from gensim.models import fasttext as fText
from sklearn.manifold import TSNE
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
from matplotlib import font_manager, rc
import fasttext as ft

model = None
vocab_list = None
adj_list = None

model = fText.load_facebook_model('./fasttext/fasttext.bin')
print("load_model_success!!")
vocab_list = open("label_list.txt", 'r', encoding="utf-8").read().split()
adj_list = open("adj_list.txt", 'r', encoding="utf-8").read().split()
# Out:
# load_model_success!!

# %%
import secrets

def makeSentence(k1,min,max):
    
    sm_A_list = []
    for vocab_item in vocab_list:
        vocab = model.similarity(vocab_item, k1)
        if vocab>min and vocab<max:
            sm_A_list.append([vocab_item, vocab])
    sm_A_list = sorted(sm_A_list, key=lambda acc: acc[1], reverse=True)
#     print(sm_A_list)
    
    select_label = secrets.choice(sm_A_list)
    print("select_label : ",select_label)
    
    adj_A_list=[]
    adj_B_list=[]
    for adj_item in adj_list:
        adj_A = model.similarity(adj_item, k1)
        adj_B = model.similarity(adj_item, select_label[0])
        adj_A_list.append([k1,select_label[0],adj_item,adj_A*adj_B])
    adj_A_list = sorted(adj_A_list, key=lambda acc: acc[3], reverse=True)
#     print(adj_A_list)
    for sentence in adj_A_list:
        print(sentence[0]+' '+sentence[2]+' '+sentence[1])


# def main():
#     k1 = '안경에'
#     k2 = '안경에'
#     makeSentence(k1,0.3,0.5)

# main()
k1 = '소리 대신에'
k2 = '진동을'
makeSentence(k1,0.3,0.5)
# Out:
# select_label :  ['뼈', 0.3366649]
# 소리 대신에 잠기는 뼈
# 소리 대신에 들이키는 뼈
# 소리 대신에 불편한 뼈
# 소리 대신에 부러진 뼈
# 소리 대신에 고급스러운 뼈
# 소리 대신에 행복한 뼈
# 소리 대신에 틀림없는 뼈
# 소리 대신에 엎드린 뼈
# 소리 대신에 들려주는 뼈
# 소리 대신에 지저분한 뼈
# 소리 대신에 손질된 뼈
# 소리 대신에 알맞은 뼈
# 소리 대신에 길어진 뼈
# 소리 대신에 내버린 뼈
# 소리 대신에 없어진 뼈
# 소리 대신에 들이마시는 뼈
# 소리 대신에 찢어진 뼈
# 소리 대신에 까만 뼈
# 소리 대신에 소용없는 뼈
# 소리 대신에 설치한 뼈
# 소리 대신에 두드리는 뼈
# 소리 대신에 춤추는 뼈
# 소리 대신에 적합한 뼈
# 소리 대신에 뒤집은 뼈
# 소리 대신에 속삭이는 뼈
# 소리 대신에 중대한 뼈
# 소리 대신에 신고된 뼈
# 소리 대신에 벗긴 뼈
# 소리 대신에 쓰다듬은 뼈
# 소리 대신에 소비한 뼈
# 소리 대신에 없는 뼈
# 소리 대신에 뛰어가는 뼈
# 소리 대신에 선호한 뼈
# 소리 대신에 영원한 뼈
# 소리 대신에 흐르는 뼈
# 소리 대신에 설명한 뼈
# 소리 대신에 들이는 뼈
# 소리 대신에 듣는 뼈
# 소리 대신에 조그마한 뼈
# 소리 대신에 쓰러진 뼈
# 소리 대신에 꺼내 뼈
# 소리 대신에 닮은 뼈
# 소리 대신에 훔치는 뼈
# 소리 대신에 튀어나오는 뼈
# 소리 대신에 소화한 뼈
# 소리 대신에 붉은 뼈
# 소리 대신에 적당한 뼈
# 소리 대신에 치료하는 뼈
# 소리 대신에 다친 뼈
# 소리 대신에 정확한 뼈
# 소리 대신에 다듬는 뼈
# 소리 대신에 굳은 뼈
# 소리 대신에 풀리는 뼈
# 소리 대신에 반짝이는 뼈
# 소리 대신에 잘못된 뼈
# 소리 대신에 나누는 뼈
# 소리 대신에 딱딱한 뼈
# 소리 대신에 재우는 뼈
# 소리 대신에 작은 뼈
# 소리 대신에 엿보는 뼈
# 소리 대신에 찌른 뼈
# 소리 대신에 끝없는 뼈
# 소리 대신에 전해지는 뼈
# 소리 대신에 배우는 뼈
# 소리 대신에 매다는 뼈
# 소리 대신에 보호한 뼈
# 소리 대신에 선택한 뼈
# 소리 대신에 완전한 뼈
# 소리 대신에 조그만 뼈
# 소리 대신에 오렴된 뼈
# 소리 대신에 다가가는 뼈
# 소리 대신에 건설한 뼈
# 소리 대신에 흰 뼈
# 소리 대신에 마시는 뼈
# 소리 대신에 밤늦은 뼈
# 소리 대신에 띄우는 뼈
# 소리 대신에 담근 뼈
# 소리 대신에 예방하는 뼈
# 소리 대신에 비는 뼈
# 소리 대신에 베는 뼈
# 소리 대신에 박힌 뼈
# 소리 대신에 개선한 뼈
# 소리 대신에 시든 뼈
# 소리 대신에 해당되는 뼈
# 소리 대신에 짧은 뼈
# 소리 대신에 도와주는 뼈
# 소리 대신에 검은 뼈
# 소리 대신에 유리한 뼈
# 소리 대신에 커다란 뼈
# 소리 대신에 화려한 뼈
# 소리 대신에 들여다본 뼈
# 소리 대신에 뛰어나오는 뼈
# 소리 대신에 수집된 뼈
# 소리 대신에 모시는 뼈
# 소리 대신에 귀중한 뼈
# 소리 대신에 집행하는 뼈
# 소리 대신에 어색한 뼈
# 소리 대신에 함께한 뼈
# 소리 대신에 만지는 뼈
# 소리 대신에 밝은 뼈
# 소리 대신에 덜어낸 뼈
# 소리 대신에 분리되는 뼈
# 소리 대신에 등장한 뼈
# 소리 대신에 강력한 뼈
# 소리 대신에 늘어놓는 뼈
# 소리 대신에 쓸데없는 뼈
# 소리 대신에 양보한 뼈
# 소리 대신에 반복하는 뼈
# 소리 대신에 팔리는 뼈
# 소리 대신에 인정되는 뼈
# 소리 대신에 평화로운 뼈
# 소리 대신에 단순한 뼈
# 소리 대신에 따뜻한 뼈
# 소리 대신에 잃어버린 뼈
# 소리 대신에 비킨 뼈
# 소리 대신에 적용되는 뼈
# 소리 대신에 신선한 뼈
# 소리 대신에 매달린 뼈
# 소리 대신에 농사짓는 뼈
# 소리 대신에 반대되는 뼈
# 소리 대신에 하얀 뼈
# 소리 대신에 부딪치는 뼈
# 소리 대신에 다니는 뼈
# 소리 대신에 비비는 뼈
# 소리 대신에 분석하는 뼈
# 소리 대신에 달려드는 뼈
# 소리 대신에 늘리는 뼈
# 소리 대신에 해당하는 뼈
# 소리 대신에 따르는 뼈
# 소리 대신에 곧은 뼈
# 소리 대신에 솔직한 뼈
# 소리 대신에 태우는 뼈
# 소리 대신에 확대한 뼈
# 소리 대신에 뽑은 뼈
# 소리 대신에 적히는 뼈
# 소리 대신에 떨리는 뼈
# 소리 대신에 새긴 뼈
# 소리 대신에 알리는 뼈
# 소리 대신에 전달된 뼈
# 소리 대신에 우승하는 뼈
# 소리 대신에 해로운 뼈
# 소리 대신에 독한 뼈
# 소리 대신에 동그란 뼈
# 소리 대신에 안정된 뼈
# 소리 대신에 풀어진 뼈
# 소리 대신에 오가는 뼈
# 소리 대신에 상당한 뼈
# 소리 대신에 막힌 뼈
# 소리 대신에 일어나는 뼈
# 소리 대신에 소개한 뼈
# 소리 대신에 싱거운 뼈
# 소리 대신에 빨간 뼈
# 소리 대신에 필요한 뼈
# 소리 대신에 집은 뼈
# 소리 대신에 불완전한 뼈
# 소리 대신에 버려진 뼈
# 소리 대신에 시작한 뼈
# 소리 대신에 시원한 뼈
# 소리 대신에 합치는 뼈
# 소리 대신에 연상하는 뼈
# 소리 대신에 환한 뼈
# 소리 대신에 분명한 뼈
# 소리 대신에 주요한 뼈
# 소리 대신에 낯선 뼈
# 소리 대신에 미끄러운 뼈
# 소리 대신에 쓴 뼈
# 소리 대신에 쓴 뼈
# 소리 대신에 흘러내린 뼈
# 소리 대신에 배는 뼈
# 소리 대신에 둥근 뼈
# 소리 대신에 뿌린 뼈
# 소리 대신에 밀접한 뼈
# 소리 대신에 노란 뼈
# 소리 대신에 적은 뼈
# 소리 대신에 들어서는 뼈
# 소리 대신에 맡기는 뼈
# 소리 대신에 적절한 뼈
# 소리 대신에 내려놓은 뼈
# 소리 대신에 감싼 뼈
# 소리 대신에 보존한 뼈
# 소리 대신에 부딪히는 뼈
# 소리 대신에 추가된 뼈
# 소리 대신에 빼앗는 뼈
# 소리 대신에 복사한 뼈
# 소리 대신에 반복되는 뼈
# 소리 대신에 두르는 뼈
# 소리 대신에 튼튼한 뼈
# 소리 대신에 감춘 뼈
# 소리 대신에 데우는 뼈
# 소리 대신에 끌어진 뼈
# 소리 대신에 나쁜 뼈
# 소리 대신에 많아진 뼈
# 소리 대신에 읽힌 뼈
# 소리 대신에 박는 뼈
# 소리 대신에 흔들리는 뼈
# 소리 대신에 식사한 뼈
# 소리 대신에 식은 뼈
# 소리 대신에 뵌 뼈
# 소리 대신에 숙인 뼈
# 소리 대신에 사라진 뼈
# 소리 대신에 때리는 뼈
# 소리 대신에 번역한 뼈
# 소리 대신에 지키는 뼈
# 소리 대신에 되돌리는 뼈
# 소리 대신에 존재하는 뼈
# 소리 대신에 더러운 뼈
# 소리 대신에 뜨거운 뼈
# 소리 대신에 키우는 뼈
# 소리 대신에 나타내는 뼈
# 소리 대신에 달려가는 뼈
# 소리 대신에 던지는 뼈
# 소리 대신에 안전한 뼈
# 소리 대신에 씻은 뼈
# 소리 대신에 재밌는 뼈
# 소리 대신에 마르는 뼈
# 소리 대신에 무의미한 뼈
# 소리 대신에 성공한 뼈
# 소리 대신에 의존하는 뼈
# 소리 대신에 완벽한 뼈
# 소리 대신에 숨은 뼈
# 소리 대신에 뛰어오는 뼈
# 소리 대신에 빠진 뼈
# 소리 대신에 긴 뼈
# 소리 대신에 흔드는 뼈
# 소리 대신에 소요된 뼈
# 소리 대신에 추가한 뼈
# 소리 대신에 미끄러진 뼈
# 소리 대신에 펴낸 뼈
# 소리 대신에 날카로운 뼈
# 소리 대신에 깨뜨린 뼈
# 소리 대신에 수행된 뼈
# 소리 대신에 중요한 뼈
# 소리 대신에 녹음하는 뼈
# 소리 대신에 불가능한 뼈
# 소리 대신에 변환하는 뼈
# 소리 대신에 찐 뼈
# 소리 대신에 생각한 뼈
# 소리 대신에 안내하는 뼈
# 소리 대신에 연결한 뼈
# 소리 대신에 빼놓은 뼈
# 소리 대신에 수리된 뼈
# 소리 대신에 터뜨린 뼈
# 소리 대신에 연구하는 뼈
# 소리 대신에 끓인 뼈
# 소리 대신에 속인 뼈
# 소리 대신에 다루는 뼈
# 소리 대신에 끓이는 뼈
# 소리 대신에 비판한 뼈
# 소리 대신에 간단한 뼈
# 소리 대신에 청소한 뼈
# 소리 대신에 띄는 뼈
# 소리 대신에 익숙한 뼈
# 소리 대신에 특별한 뼈
# 소리 대신에 수많은 뼈
# 소리 대신에 쏟아진 뼈
# 소리 대신에 더운 뼈
# 소리 대신에 큰 뼈
# 소리 대신에 요리하는 뼈
# 소리 대신에 쉰 뼈
# 소리 대신에 느끼는 뼈
# 소리 대신에 창피한 뼈
# 소리 대신에 통일한 뼈
# 소리 대신에 두꺼운 뼈
# 소리 대신에 아끼는 뼈
# 소리 대신에 전개된 뼈
# 소리 대신에 부서진 뼈
# 소리 대신에 붙인 뼈
# 소리 대신에 안긴 뼈
# 소리 대신에 구운 뼈
# 소리 대신에 섞인 뼈
# 소리 대신에 추운 뼈
# 소리 대신에 맞은 뼈
# 소리 대신에 다양해진 뼈
# 소리 대신에 멀어진 뼈
# 소리 대신에 칠하는 뼈
# 소리 대신에 들어가는 뼈
# 소리 대신에 붙는 뼈
# 소리 대신에 다른 뼈
# 소리 대신에 빠뜨린 뼈
# 소리 대신에 불린 뼈
# 소리 대신에 흐려진 뼈
# 소리 대신에 들리는 뼈
# 소리 대신에 흘러나온 뼈
# 소리 대신에 아름다운 뼈
# 소리 대신에 다름없는 뼈
# 소리 대신에 제외된 뼈
# 소리 대신에 거대한 뼈
# 소리 대신에 식힌 뼈
# 소리 대신에 위치한 뼈
# 소리 대신에 담긴 뼈
# 소리 대신에 낸 뼈
# 소리 대신에 타오르는 뼈
# 소리 대신에 비교하는 뼈
# 소리 대신에 늘어나는 뼈
# 소리 대신에 달아나는 뼈
# 소리 대신에 모는 뼈
# 소리 대신에 성장한 뼈
# 소리 대신에 따는 뼈
# 소리 대신에 일정한 뼈
# 소리 대신에 탁월한 뼈
# 소리 대신에 탈출하는 뼈
# 소리 대신에 가득한 뼈
# 소리 대신에 드러난 뼈
# 소리 대신에 불과한 뼈
# 소리 대신에 이로운 뼈
# 소리 대신에 덧붙인 뼈
# 소리 대신에 독특한 뼈
# 소리 대신에 힘든 뼈
# 소리 대신에 힘겨운 뼈
# 소리 대신에 튀기는 뼈
# 소리 대신에 대답하는 뼈
# 소리 대신에 자라난 뼈
# 소리 대신에 욕하는 뼈
# 소리 대신에 붙잡은 뼈
# 소리 대신에 절약한 뼈
# 소리 대신에 뻔한 뼈
# 소리 대신에 푸른 뼈
# 소리 대신에 맨 뼈
# 소리 대신에 소리친 뼈
# 소리 대신에 비우는 뼈
# 소리 대신에 묘사하는 뼈
# 소리 대신에 실린 뼈
# 소리 대신에 풍부한 뼈
# 소리 대신에 넘겨준 뼈
# 소리 대신에 지워진 뼈
# 소리 대신에 숨긴 뼈
# 소리 대신에 켜지는 뼈
# 소리 대신에 맛본 뼈
# 소리 대신에 색다른 뼈
# 소리 대신에 부드러운 뼈
# 소리 대신에 예약하는 뼈
# 소리 대신에 멈춘 뼈
# 소리 대신에 나타나는 뼈
# 소리 대신에 비추는 뼈
# 소리 대신에 낮은 뼈
# 소리 대신에 다가서는 뼈
# 소리 대신에 상상한 뼈
# 소리 대신에 끊임없는 뼈
# 소리 대신에 차가운 뼈
# 소리 대신에 대기하는 뼈
# 소리 대신에 등록하는 뼈
# 소리 대신에 튄 뼈
# 소리 대신에 다진 뼈
# 소리 대신에 보내는 뼈
# 소리 대신에 심은 뼈
# 소리 대신에 탄 뼈
# 소리 대신에 불가피한 뼈
# 소리 대신에 앉히는 뼈
# 소리 대신에 밝아지는 뼈
# 소리 대신에 갖은 뼈
# 소리 대신에 무거운 뼈
# 소리 대신에 집중된 뼈
# 소리 대신에 투명한 뼈
# 소리 대신에 가까운 뼈
# 소리 대신에 완성된 뼈
# 소리 대신에 활용한 뼈
# 소리 대신에 선명한 뼈
# 소리 대신에 어두운 뼈
# 소리 대신에 참가한 뼈
# 소리 대신에 대화하는 뼈
# 소리 대신에 낮아진 뼈
# 소리 대신에 방해하는 뼈
# 소리 대신에 들여놓는 뼈
# 소리 대신에 파란 뼈
# 소리 대신에 앉은 뼈
# 소리 대신에 굵은 뼈
# 소리 대신에 나은 뼈
# 소리 대신에 이용된 뼈
# 소리 대신에 쓰인 뼈
# 소리 대신에 맑은 뼈
# 소리 대신에 깬 뼈
# 소리 대신에 나뉜 뼈
# 소리 대신에 씻기는 뼈
# 소리 대신에 끼운 뼈
# 소리 대신에 끈 뼈
# 소리 대신에 비친 뼈
# 소리 대신에 특정한 뼈
# 소리 대신에 합격한 뼈
# 소리 대신에 흩어진 뼈
# 소리 대신에 말은 뼈
# 소리 대신에 해소하는 뼈
# 소리 대신에 떨어지는 뼈
# 소리 대신에 빠져나온 뼈
# 소리 대신에 안 뼈
# 소리 대신에 굳어진 뼈
# 소리 대신에 남은 뼈
# 소리 대신에 강조한 뼈
# 소리 대신에 형성되는 뼈
# 소리 대신에 비슷한 뼈
# 소리 대신에 스친 뼈
# 소리 대신에 굳힌 뼈
# 소리 대신에 요구된 뼈
# 소리 대신에 확립한 뼈
# 소리 대신에 표시하는 뼈
# 소리 대신에 뿌리친 뼈
# 소리 대신에 감소한 뼈
# 소리 대신에 실은 뼈
# 소리 대신에 쌓인 뼈
# 소리 대신에 뽑힌 뼈
# 소리 대신에 복잡한 뼈
# 소리 대신에 드문 뼈
# 소리 대신에 분리하는 뼈
# 소리 대신에 구분하는 뼈
# 소리 대신에 높은 뼈
# 소리 대신에 잦은 뼈
# 소리 대신에 낀 뼈
# 소리 대신에 향하는 뼈
# 소리 대신에 전하는 뼈
# 소리 대신에 고른 뼈
# 소리 대신에 체험하는 뼈
# 소리 대신에 운동하는 뼈
# 소리 대신에 씌운 뼈
# 소리 대신에 진한 뼈
# 소리 대신에 갑작스런 뼈
# 소리 대신에 향상되는 뼈
# 소리 대신에 흘리는 뼈
# 소리 대신에 중단하는 뼈
# 소리 대신에 유지된 뼈
# 소리 대신에 확대되는 뼈
# 소리 대신에 벌리는 뼈
# 소리 대신에 포함하는 뼈
# 소리 대신에 싱싱한 뼈
# 소리 대신에 넘긴 뼈
# 소리 대신에 흐린 뼈
# 소리 대신에 심각한 뼈
# 소리 대신에 넉넉한 뼈
# 소리 대신에 예습한 뼈
# 소리 대신에 불안한 뼈
# 소리 대신에 선물한 뼈
# 소리 대신에 소문난 뼈
# 소리 대신에 부치는 뼈
# 소리 대신에 가능한 뼈
# 소리 대신에 증가하는 뼈
# 소리 대신에 따라가는 뼈
# 소리 대신에 단단한 뼈
# 소리 대신에 거친 뼈
# 소리 대신에 댄 뼈
# 소리 대신에 꾸린 뼈
# 소리 대신에 이어진 뼈
# 소리 대신에 적어진 뼈
# 소리 대신에 간편한 뼈
# 소리 대신에 진단하는 뼈
# 소리 대신에 다양한 뼈
# 소리 대신에 뺏은 뼈
# 소리 대신에 얼린 뼈
# 소리 대신에 똑같은 뼈
# 소리 대신에 확산된 뼈
# 소리 대신에 참고하는 뼈
# 소리 대신에 기록하는 뼈
# 소리 대신에 진행된 뼈
# 소리 대신에 온 뼈
# 소리 대신에 이상한 뼈
# 소리 대신에 여긴 뼈
# 소리 대신에 비롯한 뼈
# 소리 대신에 만드는 뼈
# 소리 대신에 편 뼈
# 소리 대신에 전환한 뼈
# 소리 대신에 흘러가는 뼈
# 소리 대신에 예고하는 뼈
# 소리 대신에 건조한 뼈
# 소리 대신에 달래는 뼈
# 소리 대신에 상한 뼈
# 소리 대신에 당하는 뼈
# 소리 대신에 손쉬운 뼈
# 소리 대신에 이른 뼈
# 소리 대신에 지운 뼈
# 소리 대신에 수입된 뼈
# 소리 대신에 진출한 뼈
# 소리 대신에 빠져나간 뼈
# 소리 대신에 버리는 뼈
# 소리 대신에 높이는 뼈
# 소리 대신에 제한하는 뼈
# 소리 대신에 느린 뼈
# 소리 대신에 된 뼈
# 소리 대신에 방송하는 뼈
# 소리 대신에 제거한 뼈
# 소리 대신에 트이는 뼈
# 소리 대신에 찬 뼈
# 소리 대신에 이동한 뼈
# 소리 대신에 산 뼈
# 소리 대신에 파괴하는 뼈
# 소리 대신에 고요한 뼈
# 소리 대신에 전달하는 뼈
# 소리 대신에 설득한 뼈
# 소리 대신에 쥔 뼈
# 소리 대신에 수출된 뼈
# 소리 대신에 계산하는 뼈
# 소리 대신에 뒤늦은 뼈
# 소리 대신에 가벼운 뼈
# 소리 대신에 익숙해진 뼈
# 소리 대신에 알아낸 뼈
# 소리 대신에 작아진 뼈
# 소리 대신에 깎은 뼈
# 소리 대신에 지난 뼈
# 소리 대신에 명확한 뼈
# 소리 대신에 싼 뼈
# 소리 대신에 붙든 뼈
# 소리 대신에 충돌한 뼈
# 소리 대신에 세운 뼈
# 소리 대신에 줄어든 뼈
# 소리 대신에 보완한 뼈
# 소리 대신에 익히는 뼈
# 소리 대신에 커진 뼈
# 소리 대신에 짙은 뼈
# 소리 대신에 꺼진 뼈
# 소리 대신에 충분한 뼈
# 소리 대신에 세련된 뼈
# 소리 대신에 늙은 뼈
# 소리 대신에 주어진 뼈
# 소리 대신에 쌓은 뼈
# 소리 대신에 포함된 뼈
# 소리 대신에 강화된 뼈
# 소리 대신에 켠 뼈
# 소리 대신에 개발한 뼈
# 소리 대신에 지나친 뼈
# 소리 대신에 보도하는 뼈
# 소리 대신에 바꾸는 뼈
# 소리 대신에 모으는 뼈
# 소리 대신에 분 뼈
# 소리 대신에 많은 뼈
# 소리 대신에 집어넣은 뼈
# 소리 대신에 당기는 뼈
# 소리 대신에 값싼 뼈
# 소리 대신에 조화된 뼈
# 소리 대신에 둘러싼 뼈
# 소리 대신에 얹은 뼈
# 소리 대신에 이뤄진 뼈
# 소리 대신에 부담하는 뼈
# 소리 대신에 약한 뼈
# 소리 대신에 벌어진 뼈
# 소리 대신에 친 뼈
# 소리 대신에 지불하는 뼈
# 소리 대신에 의지된 뼈
# 소리 대신에 어두워진 뼈
# 소리 대신에 변하는 뼈
# 소리 대신에 받은 뼈
# 소리 대신에 서늘한 뼈
# 소리 대신에 한정하는 뼈
# 소리 대신에 걸친 뼈
# 소리 대신에 출발하는 뼈
# 소리 대신에 연한 뼈
# 소리 대신에 보장한 뼈
# 소리 대신에 경영하는 뼈
# 소리 대신에 편리한 뼈
# 소리 대신에 밟은 뼈
# 소리 대신에 강한 뼈
# 소리 대신에 넘친 뼈
# 소리 대신에 센 뼈
# 소리 대신에 불필요한 뼈
# 소리 대신에 같은 뼈
# 소리 대신에 짧아진 뼈
# 소리 대신에 빼는 뼈
# 소리 대신에 서명한 뼈
# 소리 대신에 더하는 뼈
# 소리 대신에 살린 뼈
# 소리 대신에 제외하는 뼈
# 소리 대신에 뛰는 뼈
# 소리 대신에 폭넓은 뼈
# 소리 대신에 개방한 뼈
# 소리 대신에 한정되는 뼈
# 소리 대신에 달라지는 뼈
# 소리 대신에 봉사하는 뼈
# 소리 대신에 이해된 뼈
# 소리 대신에 젖은 뼈
# 소리 대신에 속한 뼈
# 소리 대신에 펼쳐진 뼈
# 소리 대신에 울리는 뼈
# 소리 대신에 내놓은 뼈
# 소리 대신에 뵙는 뼈
# 소리 대신에 받아들이는 뼈
# 소리 대신에 번거로운 뼈
# 소리 대신에 끊은 뼈
# 소리 대신에 채운 뼈
# 소리 대신에 빠른 뼈
# 소리 대신에 닿는 뼈
# 소리 대신에 사용한 뼈
# 소리 대신에 시킨 뼈
# 소리 대신에 부족한 뼈
# 소리 대신에 새로운 뼈
# 소리 대신에 생산한 뼈
# 소리 대신에 편한 뼈
# 소리 대신에 턴 뼈
# 소리 대신에 반한 뼈
# 소리 대신에 푼 뼈
# 소리 대신에 요청한 뼈
# 소리 대신에 붓는 뼈
# 소리 대신에 별다른 뼈
# 소리 대신에 전개하는 뼈
# 소리 대신에 볶는 뼈
# 소리 대신에 삶은 뼈
# 소리 대신에 준 뼈
# 소리 대신에 따스한 뼈
# 소리 대신에 구별하는 뼈
# 소리 대신에 사들인 뼈
# 소리 대신에 이끈 뼈
# 소리 대신에 설립한 뼈
# 소리 대신에 캄캄한 뼈
# 소리 대신에 묻히는 뼈
# 소리 대신에 좁은 뼈
# 소리 대신에 없앤 뼈
# 소리 대신에 단 뼈
# 소리 대신에 예상하는 뼈
# 소리 대신에 열린 뼈
# 소리 대신에 꾸민 뼈
# 소리 대신에 얇은 뼈
# 소리 대신에 특이한 뼈
# 소리 대신에 간 뼈
# 소리 대신에 말하는 뼈
# 소리 대신에 되풀이하는 뼈
# 소리 대신에 정리된 뼈
# 소리 대신에 먼 뼈
# 소리 대신에 퍼지는 뼈
# 소리 대신에 썰린 뼈
# 소리 대신에 지속된 뼈
# 소리 대신에 버는 뼈
# 소리 대신에 보관한 뼈
# 소리 대신에 소유한 뼈
# 소리 대신에 용서한 뼈
# 소리 대신에 연출하는 뼈
# 소리 대신에 전시된 뼈
# 소리 대신에 정해진 뼈
# 소리 대신에 놓는 뼈
# 소리 대신에 감소된 뼈
# 소리 대신에 빛나는 뼈
# 소리 대신에 접하는 뼈
# 소리 대신에 떼는 뼈
# 소리 대신에 줄이는 뼈
# 소리 대신에 빈 뼈
# 소리 대신에 논의하는 뼈
# 소리 대신에 편안한 뼈
# 소리 대신에 넓은 뼈
# 소리 대신에 불리한 뼈
# 소리 대신에 뜨는 뼈
# 소리 대신에 떠는 뼈
# 소리 대신에 관리한 뼈
# 소리 대신에 언 뼈
# 소리 대신에 거쳐 뼈
# 소리 대신에 녹은 뼈
# 소리 대신에 제한된 뼈
# 소리 대신에 낮춘 뼈
# 소리 대신에 넣은 뼈
# 소리 대신에 깔은 뼈
# 소리 대신에 어려워진 뼈
# 소리 대신에 뱉는 뼈
# 소리 대신에 보는 뼈
# 소리 대신에 보충한 뼈
# 소리 대신에 닫는 뼈
# 소리 대신에 닦은 뼈
# 소리 대신에 연 뼈
# 소리 대신에 갖춘 뼈
# 소리 대신에 중단된 뼈
# 소리 대신에 옳은 뼈
# 소리 대신에 좁히는 뼈
# 소리 대신에 미련한 뼈
# 소리 대신에 실시한 뼈
# 소리 대신에 모집하는 뼈
# 소리 대신에 터지는 뼈
# 소리 대신에 먹는 뼈
# 소리 대신에 반영하는 뼈
# 소리 대신에 실현한 뼈
# 소리 대신에 담은 뼈
# 소리 대신에 면하는 뼈
# 소리 대신에 신청된 뼈
# 소리 대신에 형성하는 뼈
# 소리 대신에 입은 뼈
# 소리 대신에 엷은 뼈
# 소리 대신에 묻는 뼈
# 소리 대신에 뜯는 뼈
# 소리 대신에 섞은 뼈
# 소리 대신에 맡은 뼈
# 소리 대신에 미는 뼈
# 소리 대신에 얻은 뼈
# 소리 대신에 넓히는 뼈
# 소리 대신에 맺은 뼈
# 소리 대신에 빠는 뼈
# 소리 대신에 썩은 뼈
# 소리 대신에 나는 뼈
# 소리 대신에 뻗는 뼈
# 소리 대신에 깊은 뼈
# 소리 대신에 싫은 뼈
# 소리 대신에 멎은 뼈
# 소리 대신에 낡은 뼈
# 소리 대신에 노는 뼈
# 소리 대신에 선언한 뼈
# 소리 대신에 솟은 뼈
# 소리 대신에 성립한 뼈
# 소리 대신에 쏟은 뼈
# 소리 대신에 합하는 뼈
# 소리 대신에 눕는 뼈
# 소리 대신에 동일한 뼈
# C:\Users\choi\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   import sys
# C:\Users\choi\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
# C:\Users\choi\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).

# %%
def makeSentence2(k1,k2,min,max):
    sm_A_list = []
    sm_B_list = []
    for vocab_item in vocab_list:
        vocab1 = model.similarity(vocab_item, k1)
        vocab2 = model.similarity(vocab_item, k2)
        if vocab1>min and vocab1<max and vocab2>min and vocab2<max:
            sm_A_list.append([vocab_item, vocab1*vocab2])
    sm_A_list = sorted(sm_A_list, key=lambda acc: acc[1], reverse=True)
    print(sm_A_list)
    
makeSentence2(k1,k2,0.3,0.5)
# Out:
# [['젓가락', 0.17943363], ['잠자리', 0.17781824], ['뺨', 0.17632067], ['나무', 0.17443286], ['심장', 0.17354485], ['뱀', 0.17301337], ['나비', 0.17111295], ['토끼', 0.17074105], ['먹이', 0.16715756], ['술잔', 0.16585167], ['한잔', 0.1653643], ['낙엽', 0.1636346], ['병아리', 0.16294837], ['턱', 0.16249314], ['줄', 0.16196944], ['씨앗', 0.16021006], ['뼈', 0.15987173], ['수화기', 0.15860093], ['숟가락', 0.1575996], ['고기', 0.15631507], ['화살', 0.15597819], ['코끼리', 0.15556191], ['쥐', 0.15492113], ['향기', 0.15244767], ['바람', 0.15131629], ['나물', 0.15089], ['나뭇가지', 0.15074445], ['침', 0.1507125], ['악기', 0.15047032], ['습관', 0.14732313], ['떡', 0.14686795], ['연주', 0.14682496], ['후회', 0.14662592], ['소나기', 0.14571281], ['술', 0.14527313], ['냇물', 0.14486463], ['지우개', 0.14454298], ['종이', 0.14453647], ['가위', 0.14449798], ['기운', 0.14445908], ['밤', 0.14354903], ['이슬', 0.14308263], ['벌레', 0.14293616], ['바가지', 0.14285061], ['케첩', 0.14276029], ['국물', 0.14204462], ['죽', 0.14090994], ['찻잔', 0.14014877], ['뿌리', 0.13898511], ['밭', 0.13886449], ['단맛', 0.13874745], ['냄비', 0.13846809], ['환자', 0.13844194], ['주전자', 0.13781857], ['재즈', 0.13779335], ['글자', 0.13688353], ['땅바닥', 0.13639922], ['틈', 0.1355618], ['깨소금', 0.13471377], ['주머니', 0.13352267], ['과일', 0.13307548], ['고추', 0.1329572], ['꽃잎', 0.1319723], ['하늘', 0.1313326], ['꿀', 0.13025105], ['고춧가루', 0.13013013], ['수박', 0.12974453], ['팔', 0.12823212], ['해석', 0.12662832], ['까치', 0.12648402], ['책가방', 0.12642644], ['병', 0.12537073], ['이', 0.124988124], ['잎', 0.12495127], ['빨래', 0.12419261], ['깍두기', 0.12316642], ['송편', 0.12265049], ['고구마', 0.122346185], ['돌멩이', 0.120850526], ['벼', 0.120695285], ['음료수', 0.11999422], ['우유', 0.119756676], ['줄기', 0.119324096], ['동그라미', 0.118942745], ['파도', 0.1184756], ['음식', 0.11839317], ['꽃', 0.11744068], ['김치찌개', 0.11728783], ['닭고기', 0.117206566], ['종이컵', 0.115888834], ['만두', 0.11519987], ['피아노', 0.115089774], ['막걸리', 0.11490289], ['우산', 0.11461492], ['머리카락', 0.11430246], ['양주', 0.11382188], ['마요네즈', 0.11286769], ['물', 0.11064995], ['돼지고기', 0.11025489], ['사물', 0.11013878], ['콩', 0.11006316], ['소금', 0.109880626], ['쌀', 0.10943033], ['놀이', 0.10917145], ['떡국', 0.109024934], ['마라톤', 0.10894028], ['코', 0.10825649], ['김밥', 0.107577235], ['그림자', 0.107083276], ['옥수수', 0.10585739], ['녹음', 0.10530889], ['바이올린', 0.104811855], ['잔', 0.104616724], ['베개', 0.10412538], ['소주', 0.10400503], ['빵', 0.10398082], ['소나무', 0.103959896], ['밥상', 0.103951335], ['다이어트', 0.10361584], ['양배추', 0.103556074], ['숲', 0.10295531], ['설명', 0.10267349], ['분필', 0.10201855], ['멸치', 0.102006726], ['담요', 0.09838758], ['운동복', 0.09797599], ['흔적', 0.09537166], ['계란', 0.092085905]]
# C:\Users\choi\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """
# C:\Users\choi\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
