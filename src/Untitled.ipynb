# %%
from gensim.models import fasttext as fText
from sklearn.manifold import TSNE
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
from matplotlib import font_manager, rc
import fasttext as ft

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

model = ft.load_model('./fasttext/fasttext.bin');
model2 = fText.load_facebook_model('./fasttext/fasttext.bin')
print("load_model_success!!")
# Out:
# load_model_success!!

# %%
print(model.get_nearest_neighbors('휴대폰'))
model2.wv.similar_by_word('진동',topn=100)
# Out:
# [(0.8405208587646484, '핸드폰'), (0.8250108957290649, '전화'), (0.813757598400116, '휴대'), (0.8076358437538147, '휴대전화'), (0.7815715074539185, '스마트폰'), (0.7692813873291016, '전화기'), (0.7498740553855896, '호출기'), (0.736827552318573, '카메라폰'), (0.7367817759513855, '단말기'), (0.7152937650680542, 'USIM')]
# [('진동체', 0.7685884833335876),
#  ('진동음', 0.7295258641242981),
#  ('진동학', 0.7263119220733643),
#  ('진동수', 0.705950140953064),
#  ('감쇠', 0.7046409249305725),
#  ('진동만', 0.6907025575637817),
#  ('振動', 0.6880506277084351),
#  ('진동판', 0.686843752861023),
#  ('진동기', 0.6835973262786865),
#  ('초저주파', 0.6832066774368286),
#  ('진폭', 0.672991931438446),
#  ('파형', 0.6711026430130005),
#  ('공진', 0.6708915829658508),
#  ('풍하중', 0.6686394214630127),
#  ('가속계', 0.6685469150543213),
#  ('전자기파', 0.6641831994056702),
#  ('감쇄', 0.6615214943885803),
#  ('가청음', 0.6611415147781372),
#  ('진동계', 0.6602170467376709),
#  ('음파', 0.6595205068588257),
#  ('共振', 0.656995952129364),
#  ('방사주파수', 0.6546072959899902),
#  ('구면파', 0.65169358253479),
#  ('열잡음', 0.6505674123764038),
#  ('수면파', 0.647872805595398),
#  ('종진동', 0.6475059986114502),
#  ('파동', 0.6439933776855469),
#  ('가변저항', 0.639332115650177),
#  ('표면파', 0.6384737491607666),
#  ('방사압', 0.6382018327713013),
#  ('부성저항', 0.6355934143066406),
#  ('지진동', 0.6334710717201233),
#  ('쌍소멸', 0.6331533789634705),
#  ('관성', 0.6283469200134277),
#  ('잡아당김', 0.6262102723121643),
#  ('외력', 0.6257190704345703),
#  ('페이딩', 0.6252468824386597),
#  ('오동작', 0.6207501888275146),
#  ('변위', 0.6201277375221252),
#  ('비탄성', 0.6183704733848572),
#  ('횡파', 0.6171401739120483),
#  ('전자파', 0.617131769657135),
#  ('치터베베궁', 0.6167466640472412),
#  ('광전관', 0.6163280606269836),
#  ('발진기', 0.6160363554954529),
#  ('코히런트', 0.6159650087356567),
#  ('磁界', 0.6145815253257751),
#  ('초장파', 0.6138935089111328),
#  ('음향학', 0.6118557453155518),
#  ('외란', 0.6108376979827881),
#  ('소음', 0.6106579899787903),
#  ('전자기장', 0.6094784736633301),
#  ('회전각', 0.6091017127037048),
#  ('정상파', 0.608346700668335),
#  ('저주파', 0.6081207990646362),
#  ('기전력', 0.6078038215637207),
#  ('공기주', 0.6068600416183472),
#  ('電場', 0.6065558791160583),
#  ('압전기', 0.6064423322677612),
#  ('공기력', 0.6052439212799072),
#  ('준입자', 0.6051750183105469),
#  ('엑스선관', 0.6046770215034485),
#  ('鉛直', 0.6044003963470459),
#  ('감쇠력', 0.6042881011962891),
#  ('마찰력', 0.6041854619979858),
#  ('전리층', 0.6039316058158875),
#  ('진동한', 0.6033209562301636),
#  ('단진자', 0.6027307510375977),
#  ('가전자', 0.6027283668518066),
#  ('동공', 0.6024117469787598),
#  ('고른음', 0.6022900342941284),
#  ('풍향', 0.6022730469703674),
#  ('무전극', 0.6019014716148376),
#  ('전자기', 0.6016313433647156),
#  ('증폭관', 0.6010830402374268),
#  ('맴돌이', 0.6004757881164551),
#  ('磁極', 0.5998257994651794),
#  ('진북', 0.5983980298042297),
#  ('흔들림', 0.5978378653526306),
#  ('지진파', 0.5977888703346252),
#  ('진동자', 0.5971553325653076),
#  ('점도계', 0.5969216227531433),
#  ('마그네트론', 0.5967057943344116),
#  ('가속도', 0.5959656834602356),
#  ('청각기', 0.5959643721580505),
#  ('펄스', 0.5955745577812195),
#  ('기름방울', 0.5949001312255859),
#  ('다중경로', 0.5945396423339844),
#  ('반사파', 0.5939288139343262),
#  ('지진계', 0.5938670635223389),
#  ('변조파', 0.5938275456428528),
#  ('공진기', 0.5936219692230225),
#  ('편마모', 0.5932349562644958),
#  ('열전자', 0.5931761264801025),
#  ('진공계', 0.5928468704223633),
#  ('자화율', 0.5928338766098022),
#  ('주파수', 0.592826247215271),
#  ('무향실', 0.5927179455757141),
#  ('초고주파', 0.5927048921585083),
#  ('회전의', 0.5921968221664429)]

# %%
vocab_list = open("label_list.txt", 'r', encoding="utf-8").read().split()
# for vocab_item in vocab_list:
#     print(vocab_item)
# f.close()
print(len(vocab_list))

sm_A_list=[]
# sm_B_list =[]
k1 = '컴퓨터'
for vocab_item in vocab_list:
    sm_A_list.append([vocab_item,model2.similarity(vocab_item,k1)])
# print(sm_A_list)

sm_A_list = sorted(sm_A_list,key=lambda acc:acc[1],reverse=True)
print(sm_A_list)
# Out:
# 3057
# [['컴퓨터', 0.99999994], ['하드웨어', 0.8088715], ['소프트웨어', 0.7647797], ['계산기', 0.75761425], ['그래픽', 0.7105158], ['가상', 0.7017805], ['시스템', 0.7001096], ['기기', 0.68213284], ['마이크', 0.66894996], ['프린터', 0.65532064], ['기술', 0.63257754], ['사용자', 0.6283784], ['로봇', 0.62141263], ['입력', 0.6169152], ['기계', 0.61128944], ['명령어', 0.6110772], ['텍스트', 0.6087946], ['인터넷', 0.6080766], ['모니터', 0.6043564], ['도구', 0.60056734], ['전화기', 0.5992385], ['통신', 0.59878755], ['팩스', 0.59715486], ['부품', 0.5968146], ['복사기', 0.5920385], ['자판', 0.58829993], ['팩시밀리', 0.58687425], ['프로그램', 0.585773], ['스위치', 0.5822382], ['보안', 0.57139117], ['최신', 0.5689982], ['전화번호', 0.56871176], ['파일', 0.5671765], ['지능', 0.56386924], ['서비스', 0.5629953], ['휴지통', 0.5611534], ['분야', 0.5608692], ['물리학', 0.557075], ['학습', 0.55645764], ['전자', 0.5554851], ['제품', 0.5527617], ['게임', 0.54672754], ['과학', 0.54639256], ['공중전화', 0.5463488], ['타자기', 0.5451592], ['용', 0.5420503], ['비디오', 0.53968436], ['동작', 0.5392339], ['환경', 0.5390178], ['연구실', 0.53514266], ['카메라', 0.5345416], ['재생', 0.52983266], ['디스크', 0.5296794], ['수학', 0.5265323], ['논리', 0.5259076], ['영상', 0.5252945], ['테이프', 0.52341604], ['화면', 0.522861], ['장비', 0.5213063], ['교재', 0.5208497], ['매체', 0.51983786], ['계산', 0.51760715], ['장난감', 0.51746285], ['신호', 0.5172347], ['과학자', 0.51562536], ['전화', 0.51473576], ['실험', 0.51400685], ['메일', 0.5126022], ['박스', 0.5120648], ['전문가', 0.5089612], ['미디어', 0.50754905], ['테스트', 0.5073767], ['온라인', 0.5065814], ['처리', 0.50271153], ['기법', 0.50001216], ['분석', 0.49588114], ['두뇌', 0.49584097], ['전문', 0.49527502], ['초보자', 0.49465698], ['실제', 0.49420637], ['화학', 0.4933036], ['카운터', 0.49273467], ['수화기', 0.49189368], ['칠판', 0.49166724], ['레이저', 0.48946977], ['자격증', 0.48872268], ['테이블', 0.4878585], ['특수성', 0.48763984], ['기술자', 0.4871473], ['청소기', 0.48510194], ['제공', 0.48434415], ['언어', 0.48410383], ['버튼', 0.4835912], ['가능성', 0.4824969], ['기능', 0.48241544], ['한글', 0.48168823], ['특성', 0.4790816], ['접근', 0.47780156], ['기성세대', 0.47748858], ['메시지', 0.4761438], ['엔진', 0.475712], ['생활환경', 0.4739789], ['지식', 0.47260463], ['인쇄', 0.47226956], ['사물', 0.4687889], ['스튜디오', 0.46773815], ['정보', 0.46624288], ['핸드폰', 0.46484408], ['바이러스', 0.46456432], ['일반인', 0.4641974], ['동기', 0.4637694], ['게시판', 0.46287704], ['사회학', 0.46236217], ['아이디어', 0.46225792], ['작업', 0.46211314], ['에어컨', 0.4610235], ['공책', 0.46081692], ['카드', 0.46059194], ['소비자', 0.45964614], ['국어', 0.45920318], ['실습', 0.45871493], ['전용', 0.4582272], ['광고', 0.45778453], ['연락처', 0.45730639], ['복습', 0.45623904], ['용도', 0.4557583], ['주소', 0.4555125], ['플라스틱', 0.45503432], ['부서', 0.45444456], ['가정', 0.45400462], ['디자인', 0.4531608], ['사진기', 0.4524991], ['수준', 0.45204476], ['이용', 0.45122647], ['연구', 0.45113385], ['고객', 0.45043397], ['의학', 0.44980535], ['외부', 0.44901907], ['경영', 0.44846445], ['단점', 0.44841653], ['기억', 0.4478168], ['기업', 0.44605365], ['표준', 0.44531304], ['필수', 0.44501972], ['방법', 0.44493872], ['일회용', 0.44418], ['가능', 0.44403833], ['자동', 0.4435535], ['텔레비전', 0.44321048], ['채널', 0.44272712], ['망원경', 0.4417481], ['가입자', 0.44174084], ['활용', 0.4416373], ['업체', 0.44049194], ['교과서', 0.4404328], ['팩', 0.4404014], ['교육', 0.44013774], ['책상', 0.43909913], ['경제학', 0.43883747], ['이용자', 0.43864995], ['자원', 0.4386309], ['최근', 0.43808794], ['연구자', 0.43720752], ['품질', 0.4368528], ['용어', 0.43676335], ['항공기', 0.43629548], ['모델', 0.4358701], ['신제품', 0.4355867], ['공짜', 0.43546504], ['라이터', 0.4352672], ['수업', 0.43492952], ['일상생활', 0.4328705], ['문법', 0.43239373], ['이미지', 0.4323463], ['자체', 0.43224525], ['대기업', 0.43146718], ['학과', 0.43080518], ['교실', 0.43074876], ['산업', 0.43031833], ['관심사', 0.4300722], ['지원', 0.42984986], ['개인', 0.42915863], ['컬러', 0.42897943], ['시험', 0.42881012], ['디자이너', 0.42877454], ['글쓰기', 0.42862612], ['관리', 0.42859542], ['무료', 0.42748207], ['전공', 0.42654246], ['준비물', 0.4263427], ['메모', 0.42586198], ['공간', 0.4255842], ['회사', 0.42518514], ['메뉴', 0.42509577], ['엘리베이터', 0.42468464], ['음악', 0.42409772], ['피아노', 0.42292458], ['확장', 0.42265818], ['장점', 0.42260376], ['값',  ...
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   # This is added back by InteractiveShellApp.init_path()
