# %%
import fasttext

# # Skipgram model
model = fasttext.train_unsupervised('./data/corpus_mecab_jamo.txt',"skipgram")
print(model.words)
model.save_model('model_ft_sk')
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
from gensim.models import fasttext as fText
from sklearn.manifold import TSNE
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
from matplotlib import font_manager, rc
import fasttext as ft

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

model2 = fText.load_facebook_model('model_ft_sk')
print("load_model_success!!")

vocab_list = open("label_list.txt", 'r', encoding="utf-8").read().split()
for vocab_item in vocab_list:
    print(vocab_item)
# f.close()
print(len(vocab_list))

sm_A_list=[]
sm_B_list =[]
sm_AB_list =[]
k1 = '컴퓨터'
k2 = '카메라'
for vocab_item in vocab_list:
    sm_A_list.append([vocab_item,model2.similarity(vocab_item,k1)])
    sm_B_list.append([vocab_item, model2.similarity(vocab_item, k2)])
    sm_AB_list.append([vocab_item,(sm_A_list[-1][1]*0.7+sm_B_list[-1][1]*0.3)])

sm_AB_list = sorted(sm_AB_list,key=lambda acc:acc[1],reverse=True)
print(sm_AB_list)
# Out:
# load_model_success!!
# 가게
# 가격
# 가구
# 가난
# 가능
# 가능성
# 가로
# 가로등
# 가로수
# 가루
# 가뭄
# 가방
# 가사
# 가상
# 가수
# 가스
# 가슴
# 가요
# 가위
# 가을
# 가이드
# 가입
# 가입자
# 가정
# 가정교사
# 가족
# 가죽
# 가지
# 가짜
# 가치
# 가치관
# 각오
# 각종
# 간
# 간격
# 간부
# 간섭
# 간식
# 간장
# 간접
# 간판
# 간호
# 간호사
# 갈등
# 갈비
# 갈비탕
# 갈색
# 갈증
# 감
# 감각
# 감기
# 감독
# 감동
# 감사
# 감상
# 감소
# 감수성
# 감옥
# 감자
# 감정
# 값
# 강
# 강당
# 강도
# 강물
# 강변
# 강북
# 강사
# 강수량
# 강아지
# 강의
# 강제
# 강조
# 개
# 개개인
# 개구리
# 개나리
# 개미
# 개방
# 개별
# 개선
# 개성
# 개인
# 거리
# 거실
# 거액
# 거울
# 거짓
# 거짓말
# 거품
# 걱정
# 건강
# 건너
# 건너편
# 건넌방
# 건물
# 건설
# 건조
# 건축
# 걷기
# 걸음
# 검사
# 검은색
# 검정색
# 검토
# 겁
# 게
# 게시판
# 게임
# 겨울
# 겨울철
# 겨자
# 견해
# 결과
# 결석
# 결승
# 결심
# 결정
# 결혼
# 결혼식
# 경계
# 경고
# 경기
# 경기장
# 경력
# 경비
# 경영
# 경우
# 경쟁
# 경쟁력
# 경제
# 경제력
# 경제학
# 경찰
# 경찰관
# 경찰서
# 경치
# 경향
# 경험
# 계곡
# 계단
# 계란
# 계산
# 계산기
# 계약
# 계절
# 계좌
# 계층
# 계획
# 고개
# 고객
# 고구마
# 고급
# 고기
# 고등학교
# 고등학생
# 고모
# 고모부
# 고무신
# 고민
# 고생
# 고속
# 고속도로
# 고속버스
# 고양이
# 고장
# 고전
# 고집
# 고추
# 고추장
# 고춧가루
# 고통
# 고함
# 고향
# 곡
# 곡식
# 골
# 골목
# 골목길
# 골짜기
# 골치
# 골프
# 골프장
# 곰
# 곳
# 공
# 공간
# 공개
# 공격
# 공공
# 공군
# 공급
# 공기
# 공동
# 공무원
# 공부
# 공사
# 공식
# 공업
# 공연
# 공연장
# 공원
# 공장
# 공주
# 공중
# 공중전화
# 공짜
# 공책
# 공통
# 공통점
# 공포
# 공항
# 공항버스
# 공해
# 공휴일
# 과
# 과거
# 과목
# 과외
# 과일
# 과자
# 과장
# 과정
# 과제
# 과학
# 과학자
# 관객
# 관계
# 관계자
# 관광
# 관광객
# 관광버스
# 관광지
# 관념
# 관람
# 관람객
# 관련
# 관리
# 관습
# 관심
# 관심사
# 관점
# 관찰
# 광경
# 광고
# 광장
# 교과서
# 교내
# 교대
# 교류
# 교문
# 교복
# 교사
# 교수
# 교실
# 교양
# 교외
# 교육
# 교육비
# 교육자
# 교장
# 교재
# 교직
# 교체
# 교통
# 교통사고
# 교포
# 교환
# 교회
# 교훈
# 구
# 구경
# 구두
# 구름
# 구멍
# 구별
# 구분
# 구석
# 구성
# 구속
# 구역
# 구입
# 구조
# 구청
# 국
# 국가
# 국기
# 국내
# 국내선
# 국립
# 국물
# 국민
# 국사
# 국산
# 국수
# 국어
# 국왕
# 국적
# 국제
# 국제선
# 국제화
# 국회
# 국회의원
# 군
# 군대
# 군사
# 군인
# 권리
# 권위
# 권투
# 귀
# 귀가
# 귀국
# 귀신
# 귓속
# 규모
# 규정
# 규칙
# 균형
# 귤
# 그간
# 그날
# 그늘
# 그래픽
# 그룹
# 그릇
# 그리움
# 그림
# 그림자
# 그사이
# 그저께
# 그전
# 그중
# 그해
# 극
# 극복
# 극작가
# 극장
# 근거
# 근교
# 근래
# 근로
# 근로자
# 근무
# 근본
# 근원
# 근육
# 근처
# 글
# 글쓰기
# 글씨
# 글자
# 금
# 금고
# 금년
# 금메달
# 금액
# 금연
# 금요일
# 금지
# 긍정
# 기
# 기간
# 기계
# 기관
# 기구
# 기기
# 기념
# 기념일
# 기념품
# 기능
# 기대
# 기도
# 기독교
# 기둥
# 기록
# 기름
# 기법
# 기본
# 기분
# 기쁨
# 기사
# 기성
# 기성세대
# 기숙사
# 기술
# 기술자
# 기억
# 기업
# 기업인
# 기여
# 기온
# 기운
# 기원
# 기원전
# 기자
# 기적
# 기준
# 기차
# 기초
# 기침
# 기타
# 기호
# 기혼
# 기회
# 기획
# 기후
# 긴급
# 긴장
# 긴장감
# 길
# 길가
# 길거리
# 길이
# 김
# 김밥
# 김치
# 김치찌개
# 깊이
# 까닭
# 까만색
# 까치
# 깍두기
# 깡패
# 깨달음
# 깨소금
# 껌
# 껍질
# 꼬리
# 꼬마
# 꼭대기
# 꽃
# 꽃씨
# 꽃잎
# 꾸중
# 꿀
# 꿈
# 끈
# 끝
# 끼
# 나들이
# 나라
# 나머지
# 나무
# 나물
# 나뭇가지
# 나뭇잎
# 나비
# 나이
# 나중
# 나침반
# 나흘
# 낙엽
# 낚시
# 낚시꾼
# 낚싯대
# 난리
# 난방
# 날
# 날개
# 날씨
# 날짜
# 남
# 남녀
# 남동생
# 남매
# 남부
# 남북
# 남성
# 남자
# 남쪽
# 남편
# 남학생
# 낭비
# 낮
# 낱말
# 내과
# 내년
# 내달
# 내부
# 내외
# 내용
# 내용물
# 내일
# 내적
# 냄비
# 냄새
# 냇물
# 냉동
# 냉면
# 냉방
# 냉장고
# 너머
# 넥타이
# 노동
# 노동자
# 노란색
# 노래
# 노래방
# 노랫소리
# 노력
# 노선
# 노인
# 노트
# 녹색
# 녹음
# 녹차
# 녹화
# 논
# 논리
# 논문
# 논쟁
# 놀이
# 놀이터
# 농구
# 농담
# 농민
# 농부
# 농사
# 농사일
# 농산물
# 농업
# 농장
# 농촌
# 높이
# 뇌
# 누나
# 눈
# 눈가
# 눈길
# 눈동자
# 눈물
# 눈병
# 눈빛
# 눈썹
# 눈앞
# 뉴스
# 느낌
# 늑대
# 능동
# 능력
# 늦가을
# 다리
# 다방
# 다수
# 다양성
# 다음
# 다이어트
# 다툼
# 다행
# 단
# 단계
# 단골
# 단독
# 단맛
# 단순
# 단어
# 단위
# 단점
# 단지
# 단체
# 단추
# 단편
# 단풍
# 달
# 달걀
# 달러
# 달력
# 달리기
# 달빛
# 닭
# 닭고기
# 담
# 담당
# 담당자
# 담배
# 담요
# 담임
# 답
# 답변
# 답장
# 닷새
# 당근
# 당시
# 당장
# 대가
# 대개
# 대규모
# 대기
# 대기업
# 대낮
# 대다수
# 대답
# 대도시
# 대량
# 대륙
# 대문
# 대비
# 대사
# 대사관
# 대상자
# 대신
# 대응
# 대입
# 대접
# 대중
# 대중교통
# 대중문화
# 대책
# 대출
# 대통령
# 대표
# 대학
# 대학교
# 대학교수
# 대학생
# 대학원
# 대합실
# 대형
# 대화
# 대회
# 댁
# 댐
# 더위
# 덕분
# 덩어리
# 데이트
# 도
# 도구
# 도덕
# 도둑
# 도로
# 도마
# 도망
# 도서관
# 도시
# 도시락
# 도심
# 도움
# 도움말
# 도입
# 도자기
# 도장
# 도전
# 도중
# 도착
# 독감
# 독립
# 독서
# 독일어
# 독창
# 돈
# 돌
# 돌멩이
# 동그라미
# 동기
# 동네
# 동료
# 동물
# 동물원
# 동부
# 동생
# 동서
# 동서남북
# 동시
# 동아리
# 동안
# 동양
# 동양인
# 동의
# 동작
# 동전
# 동쪽
# 동창
# 동포
# 동행
# 동화
# 동화책
# 돼지
# 돼지고기
# 된장
# 된장찌개
# 두께
# 두뇌
# 두부
# 두통
# 둥지
# 뒤
# 뒤쪽
# 뒤편
# 뒷골목
# 뒷모습
# 뒷문
# 뒷산
# 드라마
# 들
# 등
# 등록
# 등록금
# 등록증
# 등산
# 등산로
# 등장
# 디스크
# 디자이너
# 디자인
# 따님
# 딸
# 딸기
# 딸아이
# 땀
# 땅
# 땅바닥
# 땅속
# 땅콩
# 때
# 떡
# 떡국
# 떡볶이
# 떼
# 뚜껑
# 뜰
# 라디오
# 라면
# 라운드
# 라이벌
# 라이터
# 라인
# 라켓
# 레몬
# 레스토랑
# 레이저
# 레저
# 렌즈
# 로봇
# 리그
# 리듬
# 마누라
# 마늘
# 마당
# 마디
# 마라톤
# 마련
# 마루
# 마무리
# 마사지
# 마약
# 마요네즈
# 마을
# 마음
# 마음가짐
# 마음속
# 마음씨
# 마이크
# 마중
# 마지막
# 마찰
# 마크
# 막걸리
# 막내
# 만남
# 만두
# 만세
# 만약
# 만일
# 만점
# 만족
# 만화
# 만화가
# 말
# 말기
# 말씀
# 말투
# 맘
# 맛
# 망원경
# 맞은편
# 매
# 매너
# 매력
# 매스컴
# 매일
# 매장
# 매체
# 맥주
# 머리
# 머리말
# 머리카락
# 머릿속
# 먹이
# 먼지
# 멋
# 메뉴
# 메모
# 메시지
# 메일
# 며느리
# 며칠
# 면
# 면담
# 면적
# 면접
# 멸치
# 명단
# 명령
# 명령어
# 명예
# 명의
# 명절
# 명칭
# 명함
# 모기
# 모니터
# 모델
# 모두
# 모래
# 모레
# 모범
# 모습
# 모양
# 모임
# 모자
# 모집
# 모퉁이
# 목
# 목걸이
# 목록
# 목사
# 목소리
# 목숨
# 목요일
# 목욕
# 목욕탕
# 목적
# 목표
# 몸
# 몸매
# 몸무게
# 몸살
# 몸속
# 몸짓
# 몸통
# 못
# 묘사
# 무
# 무게
# 무관심
# 무궁화
# 무기
# 무늬
# 무대
# 무더위
# 무덤
# 무료
# 무릎
# 무리
# 무역
# 무용
# 무용가
# 무지개
# 문
# 문구
# 문밖
# 문법
# 문서
# 문자
# 문장
# 문제
# 문제점
# 문학
# 문화
# 문화재
# 물
# 물가
# 물건
# 물결
# 물고기
# 물기
# 물론
# 물리학
# 물속
# 물음
# 물질
# 물체
# 미니
# 미디어
# 미래
# 미만
# 미사일
# 미소
# 미술
# 미술관
# 미스
# 미역
# 미용실
# 미움
# 미인
# 미팅
# 미혼
# 민간
# 민속
# 민족
# 민주
# 민주주의
# 민주화
# 믿음
# 밀가루
# 밑
# 밑바닥
# 바가지
# 바구니
# 바깥
# 바깥쪽
# 바나나
# 바늘
# 바다
# 바닥
# 바닷가
# 바닷물
# 바람
# 바보
# 바위
# 바이러스
# 바이올린
# 바지
# 바퀴
# 바탕
# 박물관
# 박사
# 박수
# 박스
# 밖
# 반
# 반대
# 반응
# 반장
# 반죽
# 반지
# 반찬
# 받침
# 발
# 발가락
# 발걸음
# 발견
# 발길
# 발끝
# 발달
# 발등
# 발레
# 발목
# 발바닥
# 발생
# 발음
# 발자국
# 발전
# 발톱
# 발표
# 밤
# 밤낮
# 밤새
# 밤중
# 밤하늘
# 밥
# 밥그릇
# 밥맛
# 밥상
# 밥솥
# 방
# 방면
# 방문
# 방바닥
# 방법
# 방송
# 방송국
# 방송사
# 방식
# 방안
# 방울
# 방지
# 방학
# 방해
# 방향
# 밭
# 배
# 배경
# 배구
# 배꼽
# 배달
# 배드민턴
# 배우
# 배우자
# 배추
# 배추김치
# 배치
# 백색
# 백성
# 백인
# 백화점
# 뱀
# 뱃사람
# 버릇
# 버섯
# 버스
# 버터
# 버튼
# 번개
# 번역
# 번지
# 번호
# 벌
# 벌금
# 벌레
# 범위
# 범인
# 범죄
# 법
# 법률
# 법원
# 법적
# 법칙
# 베개
# 벤치
# 벨트
# 벼
# 벽
# 변경
# 변동
# 변명
# 변신
# 변호사
# 변화
# 별
# 별도
# 별명
# 별일
# 병
# 병실
# 병아리
# 병원
# 보고
# 보고서
# 보관
# 보너스
# 보도
# 보라색
# 보람
# 보름
# 보리
# 보상
# 보수
# 보안
# 보자기
# 보조
# 보존
# 보통
# 보편적
# 보험
# 보호
# 복
# 복도
# 복사
# 복사기
# 복숭아
# 복습
# 볶음
# 볶음밥
# 본래
# 본부
# 본사
# 본성
# 본인
# 본질
# 볼
# 볼링
# 볼일
# 볼펜
# 봄
# 봉사
# 봉지
# 봉투
# 부
# 부근
# 부담
# 부대
# 부동산
# 부모
# 부모님
# 부문
# 부부
# 부분
# 부상
# 부서
# 부엌
# 부위
# 부인
# 부자
# 부작용
# 부잣집
# 부장
# 부재
# 부정
# 부족
# 부채
# 부처
# 부친
# 부탁
# 부품
# 부피
# 부회장
# 북
# 북부
# 북쪽
# 분량
# 분리
# 분석
# 분야
# 분위기
# 분필
# 분홍색
# 불
# 불고기
# 불교
# 불꽃
# 불만
# 불법
# 불빛
# 불안
# 불이익
# 불편
# 불평
# 불행
# 브랜드
# 블라우스
# 비
# 비교
# 비극
# 비난
# 비누
# 비닐
# 비닐봉지
# 비둘기
# 비디오
# 비만
# 비명
# 비밀
# 비바람
# 비빔밥
# 비상
# 비서
# 비용
# 비율
# 비중
# 비타민
# 비판
# 비행
# 비행기
# 비행장
# 빌딩
# 빗
# 빗물
# 빗방울
# 빗줄기
# 빚
# 빛
# 빛깔
# 빨간색
# 빨래
# 빵
# 뺨
# 뼈
# 뿌리
# 사건
# 사계절
# 사고
# 사과
# 사기
# 사나이
# 사냥
# 사람
# 사랑
# 사례
# 사립
# 사망
# 사모님
# 사무
# 사무소
# 사무실
# 사무직
# 사물
# 사방
# 사상
# 사생활
# 사설
# 사슴
# 사실
# 사업
# 사업가
# 사업자
# 사용
# 사용자
# 사원
# 사위
# 사이
# 사자
# 사장
# 사전
# 사정
# 사진
# 사진기
# 사촌
# 사춘기
# 사탕
# 사투리
# 사표
# 사회
# 사회생활
# 사회자
# 사회적
# 사회주의
# 사회학
# 사흘
# 산
# 산길
# 산부인과
# 산소
# 산속
# 산업
# 산책
# 살
# 살림
# 살인
# 삶
# 삼계탕
# 삼국
# 삼촌
# 상
# 상관
# 상금
# 상담
# 상당
# 상당수
# 상대
# 상대방
# 상대성
# 상대편
# 상류
# 상반기
# 상상
# 상상력
# 상식
# 상업
# 상인
# 상자
# 상점
# 상징
# 상처
# 상추
# 상태
# 상표
# 상품
# 상황
# 새
# 새끼
# 새벽
# 새소리
# 새우
# 새해
# 색
# 색깔
# 색연필
# 샌드위치
# 생각
# 생기
# 생명
# 생물
# 생방송
# 생산
# 생산력
# 생산자
# 생선
# 생신
# 생일
# 생활
# 생활비
# 생활수준
# 생활용품
# 생활환경
# 샤워
# 서구
# 서랍
# 서로
# 서류
# 서명
# 서민
# 서부
# 서비스
# 서양
# 서양인
# 서적
# 서점
# 서쪽
# 서클
# 석사
# 석유
# 선
# 선거
# 선물
# 선배
# 선생
# 선생님
# 선수
# 선원
# 선장
# 선전
# 선진
# 선진국
# 선택
# 선풍기
# 설거지
# 설날
# 설렁탕
# 설명
# 설문
# 설치
# 설탕
# 섬
# 섭씨
# 성
# 성격
# 성경
# 성공
# 성당
# 성명
# 성별
# 성인
# 성장
# 성적
# 성질
# 성함
# 세계
# 세계관
# 세금
# 세기
# 세대
# 세로
# 세미나
# 세상
# 세수
# 세월
# 세제
# 세탁
# 세탁기
# 세탁소
# 세트
# 센터
# 소
# 소개
# 소규모
# 소금
# 소나기
# 소나무
# 소녀
# 소년
# 소득
# 소리
# 소망
# 소매
# 소문
# 소비
# 소비자
# 소설
# 소설가
# 소속
# 소수
# 소스
# 소시지
# 소식
# 소아과
# 소원
# 소유
# 소유자
# 소음
# 소재
# 소주
# 소지품
# 소질
# 소파
# 소포
# 소풍
# 소프트웨어
# 소형
# 소화
# 속
# 속담
# 속도
# 속마음
# 속옷
# 손
# 손가락
# 손길
# 손님
# 손등
# 손목
# 손바닥
# 손발
# 손뼉
# 손수건
# 손실
# 손자
# 손잡이
# 손질
# 손톱
# 손해
# 솜
# 솜씨
# 송아지
# 송이
# 송편
# 쇠
# 쇠고기
# 쇼핑
# 수건
# 수고
# 수단
# 수도
# 수도권
# 수도꼭지
# 수돗물
# 수면
# 수명
# 수박
# 수상
# 수석
# 수술
# 수업
# 수염
# 수영
# 수영장
# 수요
# 수입
# 수입품
# 수저
# 수준
# 수집
# 수출
# 수컷
# 수표
# 수필
# 수학
# 수험생
# 수화기
# 숙녀
# 숙소
# 숙제
# 순간
# 순서
# 순수
# 순위
# 숟가락
# 술
# 술병
# 술자리
# 술잔
# 술집
# 숨
# 숫자
# 숲
# 슈퍼마켓
# 스님
# 스승
# 스웨터
# 스위치
# 스케이트
# 스케줄
# 스키
# 스키장
# 스타
# 스타일
# 스튜디오
# 스트레스
# 스포츠
# 슬픔
# 습관
# 습기
# 승객
# 승리
# 승부
# 승용차
# 승진
# 시
# 시각
# 시간
# 시계
# 시골
# 시금치
# 시기
# 시나리오
# 시내
# 시내버스
# 시대
# 시댁
# 시도
# 시디
# 시리즈
# 시멘트
# 시민
# 시부모
# 시선
# 시설
# 시스템
# 시야
# 시외
# 시외버스
# 시위
# 시인
# 시일
# 시작
# 시장
# 시절
# 시점
# 시중
# 시즌
# 시집
# 시청
# 시청률
# 시청자
# 시합
# 시험
# 식구
# 식기
# 식당
# 식량
# 식료품
# 식물
# 식빵
# 식사
# 식생활
# 식욕
# 식용유
# 식초
# 식탁
# 식품
# 식품점
# 신
# 신경
# 신고
# 신규
# 신념
# 신문
# 신문사
# 신문지
# 신발
# 신부
# 신분
# 신비
# 신사
# 신설
# 신세
# 신세대
# 신용
# 신인
# 신입생
# 신제품
# 신청
# 신청서
# 신체
# 신호
# 신호등
# 신혼부부
# 신혼여행
# 신화
# 실
# 실감
# 실내
# 실력
# 실례
# 실망
# 실수
# 실습
# 실시
# 실장
# 실정
# 실제
# 실천
# 실체
# 실태
# 실패
# 실험
# 실현
# 심리
# 심부름
# 심사
# 심장
# 심정
# 심판
# 싸움
# 싼값
# 쌀
# 쌍
# 쌍둥이
# 쓰레기
# 쓰레기통
# 쓴맛
# 씨
# 씨름
# 씨앗
# 아가씨
# 아기
# 아까
# 아나운서
# 아내
# 아드님
# 아들
# 아래
# 아래쪽
# 아래층
# 아랫사람
# 아르바이트
# 아버님
# 아버지
# 아빠
# 아쉬움
# 아스팔트
# 아이
# 아이디어
# 아이스크림
# 아줌마
# 아침
# 아파트
# 아픔
# 악기
# 악몽
# 악수
# 안
# 안개
# 안경
# 안과
# 안내
# 안방
# 안부
# 안전
# 안정
# 안주
# 안쪽
# 안팎
# 알
# 알루미늄
# 알코올
# 암
# 암시
# 암컷
# 압력
# 앞
# 앞길
# 앞날
# 앞뒤
# 앞문
# 앞바다
# 앞쪽
# 애
# 애인
# 애정
# 애초
# 액세서리
# 액수
# 앨범
# 야간
# 야구
# 야구장
# 야단
# 야외
# 야채
# 약
# 약국
# 약속
# 약수
# 약점
# 약품
# 약혼녀
# 약혼자
# 양
# 양국
# 양념
# 양력
# 양말
# 양배추
# 양보
# 양복
# 양상추
# 양식
# 양심
# 양옆
# 양주
# 양쪽
# 양파
# 얘기
# 어깨
# 어둠
# 어려움
# 어른
# 어린아이
# 어린애
# 어린이
# 어린이날
# 언니
# 언덕
# 언론
# 언어
# 얼굴
# 얼마
# 얼음
# 엄마
# 업무
# 업종
# 업체
# 엉덩이
# 엉망
# 엉터리
# 에너지
# 에어컨
# 엔진
# 엘리베이터
# 여가
# 여건
# 여고생
# 여관
# 여군
# 여권
# 여기저기
# 여대생
# 여동생
# 여럿
# 여론
# 여름
# 여름철
# 여성
# 여왕
# 여우
# 여유
# 여인
# 여자
# 여직원
# 여학생
# 여행
# 여행사
# 역
# 역사
# 역사가
# 역사상
# 역사학
# 역할
# 연간
# 연결
# 연관
# 연구
# 연구소
# 연구실
# 연구원
# 연구자
# 연극
# 연기
# 연기자
# 연두색
# 연락
# 연락처
# 연령
# 연말
# 연설
# 연세
# 연속
# 연습
# 연애
# 연예인
# 연인
# 연장
# 연주
# 연출
# 연필
# 연합
# 연휴
# 열
# 열기
# 열매
# 열쇠
# 열정
# 열차
# 열흘
# 염려
# 엽서
# 영남
# 영상
# 영양
# 영어
# 영업
# 영역
# 영웅
# 영하
# 영향
# 영향력
# 영혼
# 영화
# 영화관
# 영화배우
# 영화제
# 옆
# 옆구리
# 옆방
# 옆집
# 예
# 예감
# 예금
# 예방
# 예보
# 예비
# 예산
# 예상
# 예선
# 예술
# 예술가
# 예습
# 예식장
# 예약
# 예외
# 예의
# 예전
# 예절
# 예정
# 옛날
# 옛날이야기
# 오늘
# 오늘날
# 오락
# 오래간만
# 오래전
# 오랜만
# 오랫동안
# 오렌지
# 오른발
# 오른손
# 오른쪽
# 오리
# 오븐
# 오빠
# 오염
# 오월
# 오이
# 오전
# 오징어
# 오페라
# 오피스텔
# 오해
# 오후
# 옥상
# 옥수수
# 온도
# 온돌
# 온라인
# 온몸
# 온종일
# 올
# 올가을
# 올림픽
# 올여름
# 올해
# 옷
# 옷차림
# 와이셔츠
# 와인
# 완성
# 완전
# 왕
# 왕비
# 왕자
# 외갓집
# 외과
# 외교
# 외교관
# 외국
# 외국어
# 외국인
# 외로움
# 외모
# 외부
# 외삼촌
# 외아들
# 외제
# 외출
# 외침
# 외할머니
# 외할아버지
# 왼발
# 왼손
# 왼쪽
# 요구
# 요금
# 요리
# 요리사
# 요새
# 요일
# 요즈음
# 요즘
# 요청
# 욕
# 욕실
# 욕심
# 용
# 용기
# 용도
# 용돈
# 용서
# 용어
# 우려
# 우리나라
# 우리말
# 우산
# 우승
# 우유
# 우정
# 우주
# 우체국
# 우편
# 우표
# 운
# 운동
# 운동복
# 운동장
# 운동화
# 운명
# 운반
# 운전
# 운전기사
# 운전사
# 운전자
# 운행
# 울음
# 울음소리
# 웃어른
# 웃음
# 웃음소리
# 원
# 원고
# 원래
# 원서
# 원숭이
# 원인
# 원장
# 원피스
# 월급
# 월드컵
# 월세
# 월요일
# 웨이터
# 위
# 위기
# 위반
# 위법
# 위성
# 위원
# 위원장
# 위층
# 위치
# 위험
# 위협
# 윗몸
# 윗사람
# 유교
# 유리
# 유리창
# 유머
# 유명
# 유물
# 유산
# 유월
# 유적
# 유적지
# 유치원
# 유학
# 유학생
# 유행
# 유형
# 육군
# 육상
# 육체
# 은
# 은행
# 은행나무
# 음력
# 음료
# 음료수
# 음반
# 음식
# 음식물
# 음식점
# 음악
# 음악가
# 음주
# 의견
# 의논
# 의도
# 의류
# 의무
# 의문
# 의미
# 의복
# 의사
# 의식
# 의심
# 의욕
# 의원
# 의자
# 의지
# 의학
# 이
# 이념
# 이달
# 이데올로기
# 이동
# 이력서
# 이름
# 이마
# 이모
# 이미지
# 이민
# 이발소
# 이번
# 이별
# 이불
# 이빨
# 이사
# 이사장
# 이상
# 이성
# 이슬
# 이야기
# 이용
# 이용자
# 이웃
# 이웃집
# 이월
# 이유
# 이익
# 이자
# 이전
# 이제
# 이중
# 이하
# 이해
# 이해관계
# 이혼
# 이후
# 인
# 인간
# 인간관계
# 인간성
# 인격
# 인공
# 인구
# 인근
# 인기
# 인도
# 인류
# 인물
# 인사
# 인사말
# 인삼
# 인삼차
# 인상
# 인생
# 인쇄
# 인연
# 인원
# 인재
# 인제
# 인종
# 인체
# 인터넷
# 인터뷰
# 인하
# 인형
# 일
# 일기
# 일등
# 일반
# 일반인
# 일본어
# 일부
# 일상
# 일상생활
# 일생
# 일손
# 일식
# 일쑤
# 일월
# 일자
# 일자리
# 일정
# 일종
# 일주일
# 일체
# 일치
# 일행
# 일회용
# 일회용품
# 임금
# 임무
# 임시
# 임신
# 임신부
# 입
# 입구
# 입국
# 입대
# 입력
# 입맛
# 입사
# 입술
# 입시
# 입원
# 입장
# 입학
# 잎
# 자
# 자가용
# 자격
# 자격증
# 자극
# 자기
# 자녀
# 자동
# 자동차
# 자랑
# 자료
# 자리
# 자리
# 자매
# 자부심
# 자살
# 자세
# 자식
# 자신
# 자신감
# 자연
# 자연환경
# 자원
# 자유
# 자율
# 자장면
# 자전거
# 자정
# 자존심
# 자체
# 자취
# 자판
# 자판기
# 작가
# 작년
# 작성
# 작업
# 작용
# 작은딸
# 작은아들
# 작은아버지
# 작은어머니
# 작품
# 잔
# 잔디
# 잔디밭
# 잔치
# 잘못
# 잠
# 잠깐
# 잠바
# 잠수함
# 잠시
# 잠옷
# 잠자리
# 잡지
# 장
# 장가
# 장갑
# 장관
# 장군
# 장기간
# 장난
# 장난감
# 장남
# 장래
# 장례
# 장례식
# 장르
# 장마
# 장면
# 장모
# 장모님
# 장미
# 장비
# 장사
# 장사꾼
# 장소
# 장수
# 장식
# 장애인
# 장인
# 장점
# 장학금
# 재능
# 재료
# 재미
# 재산
# 재생
# 재수
# 재정
# 재주
# 재즈
# 재채기
# 재판
# 재학
# 재활용
# 재활용품
# 저고리
# 저녁
# 저녁때
# 저번
# 저울
# 저자
# 저축
# 적
# 적극
# 적성
# 적용
# 적응
# 전
# 전개
# 전공
# 전구
# 전국
# 전기
# 전기밥솥
# 전날
# 전달
# 전망
# 전문
# 전문가
# 전문점
# 전문직
# 전반
# 전부
# 전선
# 전설
# 전세
# 전시
# 전시장
# 전시회
# 전용
# 전자
# 전쟁
# 전철
# 전체
# 전통
# 전통문화
# 전화
# 전화기
# 전화번호
# 전환
# 전후
# 절
# 절대
# 절망
# 절반
# 절약
# 절차
# 젊은이
# 젊음
# 점
# 점검
# 점수
# 점심
# 점심때
# 점심시간
# 점원
# 접근
# 접시
# 접촉
# 젓가락
# 정
# 정거장
# 정기
# 정답
# 정당
# 정도
# 정류장
# 정리
# 정말
# 정면
# 정문
# 정반대
# 정보
# 정보화
# 정부
# 정비
# 정상
# 정성
# 정식
# 정신
# 정신과
# 정오
# 정원
# 정장
# 정지
# 정치
# 정치권
# 정치인
# 정치학
# 젖
# 제공
# 제과점
# 제목
# 제비
# 제사
# 제삿날
# 제시
# 제안
# 제약
# 제의
# 제일
# 제자
# 제자리
# 제작
# 제출
# 제품
# 제한
# 조각
# 조개
# 조건
# 조금
# 조기
# 조깅
# 조명
# 조미료
# 조사
# 조상
# 조절
# 조정
# 조직
# 조카
# 존댓말
# 존재
# 졸업
# 졸업생
# 졸음
# 종
# 종교
# 종류
# 종소리
# 종업원
# 종이
# 종이컵
# 종일
# 종합
# 좌석
# 좌우
# 죄
# 죄인
# 주거
# 주름
# 주름살
# 주말
# 주머니
# 주먹
# 주문
# 주문
# 주민
# 주방
# 주변
# 주부
# 주사
# 주소
# 주스
# 주식
# 주요
# 주위
# 주의
# 주인
# 주인공
# 주장
# 주전자
# 주제
# 주차
# 주차장
# 주택
# 주한
# 죽
# 죽음
# 준비
# 준비물
# 줄
# 줄거리
# 줄기
# 줄무늬
# 중간
# 중계방송
# 중국어
# 중국집
# 중년
# 중단
# 중독
# 중반
# 중부
# 중세
# 중소기업
# 중순
# 중식
# 중심
# 중심지
# 중앙
# 중요
# 중요성
# 중학교
# 중학생
# 쥐
# 즉석
# 즉시
# 즐거움
# 증가
# 증거
# 증권
# 증권사
# 증상
# 증세
# 지각
# 지갑
# 지구
# 지금
# 지급
# 지능
# 지대
# 지도
# 지도자
# 지름길
# 지방
# 지붕
# 지시
# 지식
# 지식인
# 지역
# 지우개
# 지원
# 지위
# 지적
# 지점
# 지지
# 지진
# 지출
# 지폐
# 지하
# 지하도
# 지하철
# 지혜
# 직선
# 직업
# 직원
# 직장
# 직장인
# 직전
# 직접
# 직후
# 진급
# 진단
# 진달래
# 진동
# 진로
# 진료
# 진리
# 진실
# 진심
# 진짜
# 진찰
# 진출
# 진통
# 진행
# 진행자
# 질
# 질문
# 질병
# 질서
# 질적
# 짐
# 짐작
# 집
# 집단
# 집안
# 집안일
# 집중
# 짓
# 짜증
# 짝
# 쪽
# 찌개
# 찌꺼기
# 차
# 차남
# 차량
# 차례
# 차림
# 차별
# 차선
# 차이
# 차이점
# 차창
# 착각
# 찬물
# 찬성
# 참가
# 참기름
# 참새
# 참석
# 참석자
# 참여
# 참외
# 참조
# 찻잔
# 창
# 창가
# 창고
# 창구
# 창문
# 창밖
# 창작
# 창조
# 채널
# 채소
# 채점
# 책
# 책가방
# 책방
# 책상
# 책임
# 책임감
# 책임자
# 챔피언
# 처녀
# 처리
# 처벌
# 처음
# 처지
# 천
# 천국
# 천둥
# 천장
# 천재
# 철
# 철도
# 철학
# 철학자
# 첫날
# 청년
# 청바지
# 청소
# 청소기
# 청소년
# 청춘
# 체력
# 체온
# 체육
# 체육관
# 체조
# 체중
# 체험
# 초기
# 초대
# 초등학교
# 초등학생
# 초록색
# 초반
# 초밥
# 초보
# 초보자
# 초상화
# 초순
# 초여름
# 초원
# 초저녁
# 초점
# 초청
# 초청장
# 초콜릿
# 촛불
# 총
# 총각
# 총리
# 총장
# 촬영
# 최고
# 최고급
# 최근
# 최대
# 최상
# 최선
# 최소
# 최신
# 최악
# 최저
# 최종
# 최초
# 최후
# 추가
# 추석
# 추억
# 추위
# 추진
# 추천
# 추측
# 축구
# 축구공
# 축구장
# 축소
# 축제
# 축하
# 출구
# 출국
# 출근
# 출발
# 출발점
# 출산
# 출신
# 출연
# 출입
# 출입국
# 출입문
# 출장
# 출퇴근
# 출판
# 출판사
# 춤
# 충격
# 충고
# 충돌
# 취미
# 취소
# 취업
# 취재
# 취직
# 취향
# 층
# 치과
# 치료
# 치료법
# 치마
# 치아
# 치약
# 치즈
# 친구
# 친절
# 친정
# 친척
# 칠월
# 칠판
# 침
# 침대
# 침묵
# 침실
# 칫솔
# 칭찬
# 카드
# 카레
# 카메라
# 카운터
# 카페
# 칸
# 칼
# 칼국수
# 캐릭터
# 캠퍼스
# 캠페인
# 커튼
# 커피
# 컨디션
# 컬러
# 컴퓨터
# 컵
# 케첩
# 코
# 코끝
# 코끼리
# 코너
# 코드
# 코미디
# 코스
# 코스모스
# 코치
# 코트
# 코피
# 콘서트
# 콜라
# 콤플렉스
# 콩
# 콩나물
# 쾌감
# 크기
# 크리스마스
# 크림
# 큰길
# 큰소리
# 큰일
# 큰절
# 클래식
# 클럽
# 키
# 키스
# 타락
# 타입
# 타자기
# 탁구
# 탁자
# 탄생
# 탑
# 탓
# 태권도
# 태도
# 태아
# 태양
# 태풍
# 택시
# 탤런트
# 터
# 터널
# 터미널
# 턱
# 털
# 테니스
# 테러
# 테스트
# 테이블
# 테이프
# 텍스트
# 텔레비전
# 토끼
# 토대
# 토론
# 토론자
# 토론회
# 토마토
# 토요일
# 통
# 통계
# 통과
# 통로
# 통신
# 통역
# 통일
# 통장
# 통제
# 통증
# 통합
# 통화
# 퇴근
# 퇴원
# 퇴직금
# 투자
# 투표
# 튀김
# 트럭
# 특급
# 특별
# 특성
# 특수
# 특수성
# 특징
# 틀
# 틈
# 티브이
# 티셔츠
# 팀
# 파
# 파도
# 파란색
# 파리
# 파일
# 파출소
# 파티
# 판
# 판결
# 판단
# 판매
# 판사
# 팔
# 팔월
# 팝송
# 패션
# 팩
# 팩스
# 팩시밀리
# 팬
# 팬티
# 페인트
# 편견
# 편의
# 편의점
# 편지
# 평가
# 평균
# 평상시
# 평생
# 평소
# 평일
# 평화
# 폐지
# 포도
# 포도주
# 포스터
# 포인트
# 포장
# 포장마차
# 포크
# 포함
# 폭
# 폭력
# 표
# 표면
# 표시
# 표정
# 표준
# 표현
# 풀
# 품
# 품목
# 품질
# 풍경
# 풍속
# 풍습
# 프로
# 프로그램
# 프린터
# 플라스틱
# 피
# 피곤
# 피디
# 피로
# 피망
# 피부
# 피시
# 피아노
# 피자
# 피해
# 피해자
# 필름
# 필수
# 필요
# 필요성
# 필자
# 필통
# 핑계
# 하
# 하나
# 하나님
# 하느님
# 하늘
# 하드웨어
# 하루
# 하숙집
# 하순
# 하얀색
# 하천
# 하품
# 학과
# 학교
# 학교생활
# 학급
# 학기
# 학년
# 학력
# 학번
# 학부모
# 학비
# 학생
# 학생증
# 학술
# 학습
# 학용품
# 학원
# 학위
# 학자
# 학점
# 한
# 한겨울
# 한계
# 한구석
# 한국말
# 한국어
# 한글
# 한글날
# 한낮
# 한눈
# 한마디
# 한문
# 한밤중
# 한번
# 한복
# 한순간
# 한숨
# 한식
# 한자
# 한잔
# 한쪽
# 한참
# 한편
# 한평생
# 할머니
# 할아버지
# 할인
# 합격
# 항공
# 항공기
# 항구
# 항의
# 해
# 해결
# 해군
# 해답
# 해당
# 해물
# 해석
# 해설
# 해소
# 해수욕장
# 해안
# 해외
# 해외여행
# 핵
# 핵심
# 핸드백
# 핸드폰
# 햄
# 햄버거
# 햇볕
# 햇빛
# 햇살
# 행동
# 행복
# 행사
# 행운
# 행위
# 향
# 향기
# 향상
# 향수
# 허가
# 허락
# 허리
# 허용
# 헬기
# 혀
# 현관
# 현관문
# 현금
# 현대
# 현대인
# 현상
# 현실
# 현장
# 현재
# 현지
# 혈액
# 협력
# 형
# 형님
# 형부
# 형사
# 형성
# 형수
# 형식
# 형제
# 형태
# 형편
# 혜택
# 호기심
# 호남
# 호랑이
# 호박
# 호수
# 호실
# 호주머니
# 호텔
# 호흡
# 혼자
# 혼잣말
# 홈페이지
# 홍보
# 홍수
# 홍차
# 화
# 화가
# 화면
# 화분
# 화살
# 화장
# 화장실
# 화장지
# 화장품
# 화재
# 화제
# 화학
# 확보
# 확신
# 확인
# 확장
# 확정
# 환갑
# 환경
# 환경오염
# 환영
# 환율
# 환자
# 활기
# 활동
# 활용
# 회견
# 회관
# 회복
# 회사
# 회색
# 회원
# 회의
# 회장
# 회전
# 회화
# 횟수
# 횡단보도
# 효과
# 효도
# 효자
# 후
# 후기
# 후반
# 후배
# 후보
# 후춧가루
# 후회
# 훈련
# 휴가
# 휴식
# 휴일
# 휴지
# 휴지통
# 흉내
# 흐름
# 흑백
# 흑인
# 흔적
# 흙
# 흥미
# 흥분
# 희곡
# 희망
# 희생
# 흰색
# 힘
# 3057
# C:\Users\choi\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
# C:\Users\choi\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
# [['컴퓨터', 0.6381790071725845], ['통역', 0.29799858331680296], ['지원', 0.27150752022862434], ['국민', 0.2619430348277092], ['제사', 0.2609911940991878], ['자판', 0.26048768162727354], ['등록증', 0.26032293103635307], ['활기', 0.25634530335664746], ['배치', 0.25280898734927176], ['시내버스', 0.24769390374422073], ['살인', 0.24488929212093352], ['약속', 0.2435959845781326], ['만세', 0.24142820537090298], ['물리학', 0.23312961906194685], ['시나리오', 0.23285343348979948], ['낚싯대', 0.23030402213335038], ['계절', 0.2300005972385406], ['대문', 0.22869489341974253], ['인터뷰', 0.22631154060363767], ['여군', 0.22424020618200302], ['된장찌개', 0.22408364936709405], ['운동화', 0.2220227375626564], ['파도', 0.2219206504523754], ['티셔츠', 0.22021068930625914], ['여행사', 0.21998132690787314], ['실수', 0.21916742920875548], ['간접', 0.2175626732409], ['인근', 0.21644065529108047], ['근무', 0.2153186187148094], ['알코올', 0.21204400770366189], ['몸살', 0.21174415498971938], ['핵', 0.2107832081615925], ['출입국', 0.2107186496257782], ['고함', 0.20951426327228545], ['물건', 0.20894019603729247], ['커튼', 0.20839646197855471], ['국어', 0.2062969386577606], ['계획', 0.20616416484117506], ['복사', 0.20601504258811473], ['강사', 0.20583923235535623], ['동양', 0.20571338832378389], ['요구', 0.2057132601737976], ['과', 0.20528979524970054], ['외국어', 0.20393666326999663], ['원숭이', 0.20343113541603086], ['소규모', 0.20246931910514832], ['허용', 0.2019145771861076], ['순서', 0.20133045390248297], ['주차장', 0.20107823610305786], ['댁', 0.1984938144683838], ['냉동', 0.19640421867370603], ['치료', 0.19527969062328338], ['공식', 0.19500282257795332], ['경향', 0.19499471187591552], ['땅', 0.19311557859182357], ['대입', 0.19287228770554066], ['창작', 0.19284605011343955], ['토론자', 0.19273512139916418], ['아랫사람', 0.19224494844675064], ['학점', 0.19218103885650634], ['볶음밥', 0.19206144511699677], ['소금', 0.19120788797736168], ['의사', 0.19119777381420133], ['축구장', 0.1898566722869873], ['주차', 0.18971525877714157], ['프린터', 0.1893901478499174], ['삼계탕', 0.18892428204417228], ['조개', 0.18822214603424073], ['반지', 0.18817065358161925], ['산부인과', 0.18800816535949705], ['줄무늬', 0.18761276900768278], ['노동자', 0.1874694988131523], ['종업원', 0.18741183336824177], ['문제점', 0.18669458720833063], ['대학원', 0.18535463903099297], ['오늘날', 0.18415518552064894], ['규정', 0.1841383811086416], ['이해관계', 0.18386309593915937], ['빛깔', 0.18266618475317956], ['비타민', 0.17855020016431808], ['독창', 0.17852432131767274], ['발등', 0.17795578986406324], ['설렁탕', 0.1777356907725334], ['옷', 0.17761780321598053], ['개나리', 0.17669254411011934], ['연결', 0.17642650455236433], ['사용', 0.17587984800338746], ['눈썹', 0.17482309639453888], ['경기장', 0.17477882597595454], ['원서', 0.1732855036854744], ['능동', 0.17304024547338484], ['승부', 0.17120888531208037], ['소아과', 0.17098043002188204], ['안과', 0.1707297183573246], ['가족', 0.1698570117354393], ['자동차', 0.16898250505328177], ['자존심', 0.16865656375885008], ['정문', 0.16834730058908462], ['아빠', 0.16814323216676713], ['실패', 0.16809897124767303], ['건넌방', 0.16788179725408553], ['어깨', 0.1676461711525917], ['논문', 0.167495059967041], ['녹화', 0.1669566422700882], ['이', 0.1663708075881004], ['상징', 0.1662877261638641], ['후춧가루', 0.16608818545937537], ['여행', 0.1657747134566307], ['미용실', 0.16367720477283], ['연출', 0.16366809979081154], ['종합', 0.16277970671653746], ['발톱', 0.1627008132636547], ['숲', 0.1626164853572845], ['규모', 0.16240420825779436], ['절반', 0.16201494559645652], ['임시', 0.16133351773023605], ['오월', 0.16106162443757055], ['퇴근', 0.16090344712138177], ['벤치', 0.1608554020524025], ['추석', 0.1604280389845371], ['구별', 0.16035448461771012], ['질병', 0.15945274606347082], ['얼마', 0.15924466401338577], ['책방', 0.15905798375606536], ['용기', 0.15905426964163777], ['유학생', 0.15897601544857026], ['호흡', 0.15897214114665986], ['불꽃', 0.15860428512096406], ['소망', 0.15827551633119583], ['오래전', 0.1580595716834068], ['분리', 0.15782170817255972], ['반죽', 0.1577151119709015], ['해안', 0.15766000896692275], ['학술', 0.1569487124681473], ['총각', 0.15664558187127114], ['대규모', 0.1561229795217514], ['울음', 0.15595760941505432], ['카메라', 0.1557510167360306 ...
